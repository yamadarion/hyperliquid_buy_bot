# %%
#必要なライブラリとモジュールのインポート
import json
import ccxt
import pandas as pd
import numpy as np
import talib
from datetime import datetime, timedelta

# %%
#基本情報の設定
# APIキーの読み込み
with open("api_key.json", "r") as f:
    api_keys = json.load(f)

# 環境設定
TEST_MODE = False  # True: テスト環境, False: 本番環境
PIPS = 0.001  # 価格の最小単位（例: pips）

# CCXTでのAPI設定
exchange = ccxt.hyperliquid({
    "apiKey": api_keys["apiKey"],
    "privateKey": api_keys["privateKey"],
    "walletAddress": api_keys["walletaddress"],
    "timeout": 20000  # タイムアウトを20秒に設定
})

#ウォレットアドレスの取得
walletAddress=api_keys['walletaddress']

exchange.verbose = False  # デバッグ情報を非表示にする
exchange.load_markets()

print("owatta")
# Out:
# owatta

# %%
#データフレームの作成
# 通貨ペアと期間
symbol = "HYPE/USDC:USDC"
timeframe = "1m"  # 時間足（1分足）
atr_period = 14  # ATRの期間

# OHLCデータ取得
def fetch_ohlc_data(symbol, timeframe, since):
    ohlc = exchange.fetch_ohlcv(symbol, timeframe, since=since)
    df = pd.DataFrame(ohlc, columns=["timestamp", "open", "high", "low", "close", "volume"])
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
    return df

# ATRの計算
def calculate_atr(df, period):
    df["ATR"] = talib.ATR(df["high"], df["low"], df["close"], timeperiod=period)
    return df

# 指値価格の計算
def calculate_limit_price(df, pips):
    df["limit_price_dist"] = df["ATR"] * 0.5  # ハイパーパラメータ
    df["limit_price_dist"] = np.maximum(1, (df["limit_price_dist"] / pips).round().fillna(1)) * pips
    return df

# レバレッジ設定
#def set_leverage(symbol, leverage): #hyperliquidのccxtはset_leverageをサポートしていない。
    #try:
        #response = exchange.private_post_set_leverage({
           # "symbol": symbol,
           # "leverage": leverage
       # })
       # print(f"Leverage set to {leverage}x for {symbol}: {response}")
    #except Exception as e:
        #print(f"Failed to set leverage: {e}")

print("owatta")

# USDCの残高を取得
def get_usdc_balance():
    try:
        balance = exchange.fetch_balance(params={"user": api_keys["walletaddress"]})
        usdc_balance = balance.get("USDC", {}).get("free", 0)  # USDCのフリーバランスを取得
        return usdc_balance
    except Exception as e:
        print(f"Failed to fetch USDC balance: {e}")
        return 0

# 証拠金残高を確認 (USDCのみ)
def check_margin(symbol, amount, price, leverage):
    try:
        if price is None or price <= 0:
            print("Invalid price for margin check.")
            return False
        required_margin = (amount * float(price)) / leverage
        usdc_balance = get_usdc_balance()  # get_usdc_balanceを再利用
        if usdc_balance < required_margin:
            print(f"Insufficient margin: Required {required_margin}, Available {usdc_balance}")
            return False
        return True
    except Exception as e:
        print(f"Failed to fetch margin information: {e}")
        return False
# Out:
# owatta

# %%
def calculate_dynamic_order_amount(walletAddress, leverage, price):
    """
    動的な注文量を計算 (USDCベース -> HYPE単位に変換)
    - 指定された価格（price）でUSDCをHYPE単位に変換
    """
    usdc_balance = get_usdc_balance()
    if usdc_balance <= 0:
        print("Insufficient balance.")
        return 0.0

    # 動的注文量をUSDCで計算
    dynamic_amount_usdc = usdc_balance * 3 * 0.05 #レバレッジ設定ができる場合は"usdc_balance * leverage * 0.05"

    # HYPE単位に変換
    amount_in_hype = dynamic_amount_usdc / price  # USDCを価格で割りHYPE単位に
    symbol_info = exchange.market(symbol)
    min_amount = symbol_info['limits']['amount']['min'] or 0.4  # 最小取引量

    # 最小単位を考慮して丸める
    amount_in_hype = max(min_amount, round(amount_in_hype, 6))

    print(f"Dynamic order amount (HYPE): {amount_in_hype} (Based on USDC: {dynamic_amount_usdc} and Price: {price})")
    return amount_in_hype

def place_orders_based_on_strategy(df, symbol, walletAddress, leverage):
    """
    売買戦略に基づいて指値注文を送信
    - 指値金額を利用して注文量を計算
    """
    last_row = df.iloc[-1]
    buy_price = last_row['buy_price']
    #sell_price = last_row['sell_price']

    # 買い注文量を計算
    buy_amount = calculate_dynamic_order_amount(walletAddress, leverage, buy_price)
    return buy_amount
    # 売り注文量を計算
    #sell_amount = calculate_dynamic_order_amount(walletAddress, leverage, sell_price)

    # 買い注文を送信
    #place_order(symbol, "buy", buy_amount, buy_price, leverage)
    # 売り注文を送信
    #place_order(symbol, "sell", sell_amount, sell_price, leverage)

# %%
import time
import numpy as np
from datetime import datetime, timedelta, timezone
from decimal import Decimal

# ATRで指値距離を計算
def calculate_limit_price(df, pips):
    df['limit_price_dist'] = df['ATR'] * 0.5
    df['limit_price_dist'] = np.maximum(1, (df['limit_price_dist'] / pips).round().fillna(1)) * pips
    df['buy_price'] = df['close'] - df['limit_price_dist']

    return df

open_positions = {}  # シンボルごとの保有ポジションを管理

def place_order(symbol, amount, price, leverage):
    """
    新規注文を作成
    :param str symbol: 取引ペア
    :param float amount: 注文量
    :param float price: 注文価格
    :param float leverage: レバレッジ
    """
    if TEST_MODE:
        print(f"[TEST MODE] Order simulated: buy {amount} {symbol} at {price} with leverage {leverage}x")
        open_positions[symbol] = {"entry_price": price, "amount": amount}
    else:
        try:
            params = {
                "privateKey": api_keys["privateKey"],
                "walletAddress": api_keys["walletaddress"]
            }
            exchange.create_limit_order(symbol, "buy", amount, price, params=params)
            open_positions[symbol] = {"entry_price": price, "amount": amount}
            print(f"Order placed: buy {amount} {symbol} at {price}")
        except Exception as e:
            print(f"Failed to place order: {e}")

def place_reduce_only_order(symbol, amount, price):
    """
    Reduce-Onlyの指値注文を作成
    :param str symbol: 取引ペア
    :param float amount: 注文量
    :param float price: 指値価格
    """
    if TEST_MODE:
        print(f"[TEST MODE] Reduce-Only Order simulated: sell {amount} {symbol} at {price}")
    else:
        try:
            params = {"reduceOnly": True}
            exchange.create_limit_order(symbol, "sell", amount, price, params=params)
            print(f"Reduce-Only Order placed: sell {amount} {symbol} at {price}")
        except Exception as e:
            print(f"Failed to place reduce-only order: {e}")

def manage_positions(df, symbol):
    """
    現在のポジションを管理し、必要に応じて決済注文を出す
    :param DataFrame df: データフレーム
    :param str symbol: 取引ペア
    """
    if symbol not in open_positions:
        print("No open positions to manage.")
        return

    last_row = df.iloc[-1]
    entry_price = open_positions[symbol]['entry_price']
    position_amount = open_positions[symbol]['amount']
    close_price = last_row['close']
    limit_price_dist = last_row['limit_price_dist']

    if close_price > entry_price:
        tp_price = close_price + limit_price_dist
        place_reduce_only_order(symbol, position_amount, tp_price)
    else:
        print("Close price is not higher than entry price. No action taken.")

# トレーディングボット本体
def trading_bot():
    since = int((datetime.now(timezone.utc) - timedelta(minutes=atr_period + 1)).timestamp() * 1000)
    df = fetch_ohlc_data(symbol, timeframe, since)
    if df.empty:
        print("No data fetched. Retrying...")
        return None

    df = calculate_limit_price(calculate_atr(df, atr_period), PIPS)

    leverage = 3  # レバレッジ
    buy_price = df.iloc[-1]['buy_price']
    amount = calculate_dynamic_order_amount(walletAddress, leverage, buy_price)

    # 新規注文
    place_order(symbol, amount, buy_price, leverage)

    # ポジション管理
    manage_positions(df, symbol)

    return df

# テスト用フラグ
SINGLE_RUN = False  # True: 単発実行, False: 無限ループ

if __name__ == "__main__":
    try:
        if SINGLE_RUN:
            df = trading_bot()
            if df is not None:
                print(df)
            print("Single run complete.")
        else:
            while True:
                df = trading_bot()
                if df is not None:
                    print(df)
                print("Waiting for the next cycle...")
                time.sleep(60)
    except KeyboardInterrupt:
        print("Bot stopped manually.")
    except Exception as e:
        print(f"Error running bot: {e}")
# Out:
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 8.6773644 and Price: 26.298)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.298
# Failed to place reduce-only order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Reduce only order would increase position. asset=159"}]}}}
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:38:00  26.464  26.491  26.433  26.482   2302.12       NaN
# 1  2024-12-18 13:39:00  26.482  26.495  26.438  26.458   5266.44       NaN
# 2  2024-12-18 13:40:00  26.458  26.530  26.448  26.471   4434.04       NaN
# 3  2024-12-18 13:41:00  26.484  26.494  26.379  26.380   9515.14       NaN
# 4  2024-12-18 13:42:00  26.379  26.479  26.352  26.454   4128.58       NaN
# 5  2024-12-18 13:43:00  26.427  26.480  26.389  26.392   4153.64       NaN
# 6  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83       NaN
# 7  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08       NaN
# 8  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85       NaN
# 9  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 10 2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 11 2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 12 2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 13 2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 14 2024-12-18 13:52:00  26.360  26.366  26.360  26.366     39.18  0.136571
#
#     limit_price_dist  buy_price
# 0              0.001     26.481
# 1              0.001     26.457
# 2              0.001     26.470
# 3              0.001     26.379
# 4              0.001     26.453
# 5              0.001     26.391
# 6              0.001     26.199
# 7              0.001     26.384
# 8              0.001     26.567
# 9              0.001     26.340
# 10             0.001     26.484
# 11             0.001     26.420
# 12             0.001     26.366
# 13             0.001     26.361
# 14             0.068     26.298
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 6.825678750000001 and Price: 26.129)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.129
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.273
#              timestamp    open    high     low   close    volume    ATR  \
# 0  2024-12-18 13:39:00  26.482  26.495  26.438  26.458   5266.44    NaN
# 1  2024-12-18 13:40:00  26.458  26.530  26.448  26.471   4434.04    NaN
# 2  2024-12-18 13:41:00  26.484  26.494  26.379  26.380   9515.14    NaN
# 3  2024-12-18 13:42:00  26.379  26.479  26.352  26.454   4128.58    NaN
# 4  2024-12-18 13:43:00  26.427  26.480  26.389  26.392   4153.64    NaN
# 5  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83    NaN
# 6  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08    NaN
# 7  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85    NaN
# 8  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14    NaN
# 9  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89    NaN
# 10 2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57    NaN
# 11 2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81    NaN
# 12 2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10    NaN
# 13 2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46    NaN
# 14 2024-12-18 13:53:00  26.212  26.212  26.201  26.201     37.77  0.145
#
#     limit_price_dist  buy_price
# 0              0.001     26.457
# 1              0.001     26.470
# 2              0.001     26.379
# 3              0.001     26.453
# 4              0.001     26.391
# 5              0.001     26.199
# 6              0.001     26.384
# 7              0.001     26.567
# 8              0.001     26.340
# 9              0.001     26.484
# 10             0.001     26.420
# 11             0.001     26.366
# 12             0.001     26.361
# 13             0.001     26.214
# 14             0.072     26.129
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 5.3032908 and Price: 26.17)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.17
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.314
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:40:00  26.458  26.530  26.448  26.471   4434.04       NaN
# 1  2024-12-18 13:41:00  26.484  26.494  26.379  26.380   9515.14       NaN
# 2  2024-12-18 13:42:00  26.379  26.479  26.352  26.454   4128.58       NaN
# 3  2024-12-18 13:43:00  26.427  26.480  26.389  26.392   4153.64       NaN
# 4  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83       NaN
# 5  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08       NaN
# 6  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85       NaN
# 7  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 8  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 9  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 10 2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 11 2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 12 2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 13 2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 14 2024-12-18 13:54:00  26.239  26.242  26.218  26.242    217.40  0.144071
#
#     limit_price_dist  buy_price
# 0              0.001     26.470
# 1              0.001     26.379
# 2              0.001     26.453
# 3              0.001     26.391
# 4              0.001     26.199
# 5              0.001     26.384
# 6              0.001     26.567
# 7              0.001     26.340
# 8              0.001     26.484
# 9              0.001     26.420
# 10             0.001     26.366
# 11             0.001     26.361
# 12             0.001     26.214
# 13             0.001     26.215
# 14             0.072     26.170
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 5.3180362500000005 and Price: 26.194)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.194
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.336000000000002
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:41:00  26.484  26.494  26.379  26.380   9515.14       NaN
# 1  2024-12-18 13:42:00  26.379  26.479  26.352  26.454   4128.58       NaN
# 2  2024-12-18 13:43:00  26.427  26.480  26.389  26.392   4153.64       NaN
# 3  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83       NaN
# 4  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08       NaN
# 5  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85       NaN
# 6  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 7  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 8  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 9  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 10 2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 11 2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 12 2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 13 2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 14 2024-12-18 13:55:00  26.266  26.266  26.252  26.265     11.14  0.141857
#
#     limit_price_dist  buy_price
# 0              0.001     26.379
# 1              0.001     26.453
# 2              0.001     26.391
# 3              0.001     26.199
# 4              0.001     26.384
# 5              0.001     26.567
# 6              0.001     26.340
# 7              0.001     26.484
# 8              0.001     26.420
# 9              0.001     26.366
# 10             0.001     26.361
# 11             0.001     26.214
# 12             0.001     26.215
# 13             0.001     26.251
# 14             0.071     26.194
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 4.0181467500000005 and Price: 26.148)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.148
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.285999999999998
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:42:00  26.379  26.479  26.352  26.454   4128.58       NaN
# 1  2024-12-18 13:43:00  26.427  26.480  26.389  26.392   4153.64       NaN
# 2  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83       NaN
# 3  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08       NaN
# 4  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85       NaN
# 5  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 6  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 7  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 8  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 9  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 10 2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 11 2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 12 2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 13 2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 14 2024-12-18 13:56:00  26.245  26.245  26.202  26.217   1067.28  0.137786
#
#     limit_price_dist  buy_price
# 0              0.001     26.453
# 1              0.001     26.391
# 2              0.001     26.199
# 3              0.001     26.384
# 4              0.001     26.567
# 5              0.001     26.340
# 6              0.001     26.484
# 7              0.001     26.420
# 8              0.001     26.366
# 9              0.001     26.361
# 10             0.001     26.214
# 11             0.001     26.215
# 12             0.001     26.251
# 13             0.001     26.226
# 14             0.069     26.148
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 2.9322837 and Price: 26.134)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.134
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.268
#              timestamp    open    high     low   close    volume     ATR  \
# 0  2024-12-18 13:43:00  26.427  26.480  26.389  26.392   4153.64     NaN
# 1  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83     NaN
# 2  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08     NaN
# 3  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85     NaN
# 4  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14     NaN
# 5  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89     NaN
# 6  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57     NaN
# 7  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81     NaN
# 8  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10     NaN
# 9  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46     NaN
# 10 2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16     NaN
# 11 2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29     NaN
# 12 2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50     NaN
# 13 2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81     NaN
# 14 2024-12-18 13:57:00  26.238  26.239  26.201  26.201    902.42  0.1345
#
#     limit_price_dist  buy_price
# 0              0.001     26.391
# 1              0.001     26.199
# 2              0.001     26.384
# 3              0.001     26.567
# 4              0.001     26.340
# 5              0.001     26.484
# 6              0.001     26.420
# 7              0.001     26.366
# 8              0.001     26.361
# 9              0.001     26.214
# 10             0.001     26.215
# 11             0.001     26.251
# 12             0.001     26.226
# 13             0.001     26.216
# 14             0.067     26.134
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 3.37436595 and Price: 26.043)
# Order placed: buy 0.4 HYPE/USDC:USDC at 26.043
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.177
#              timestamp    open    high     low   close    volume    ATR  \
# 0  2024-12-18 13:44:00  26.392  26.429  26.200  26.200  11360.83    NaN
# 1  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08    NaN
# 2  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85    NaN
# 3  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14    NaN
# 4  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89    NaN
# 5  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57    NaN
# 6  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81    NaN
# 7  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10    NaN
# 8  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46    NaN
# 9  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16    NaN
# 10 2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29    NaN
# 11 2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50    NaN
# 12 2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81    NaN
# 13 2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94    NaN
# 14 2024-12-18 13:58:00  26.161  26.164  26.072  26.110   4898.01  0.133
#
#     limit_price_dist  buy_price
# 0              0.001     26.199
# 1              0.001     26.384
# 2              0.001     26.567
# 3              0.001     26.340
# 4              0.001     26.484
# 5              0.001     26.420
# 6              0.001     26.366
# 7              0.001     26.361
# 8              0.001     26.214
# 9              0.001     26.215
# 10             0.001     26.251
# 11             0.001     26.226
# 12             0.001     26.216
# 13             0.001     26.150
# 14             0.067     26.043
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 2.7877635000000005 and Price: 25.934)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.934
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.066
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:45:00  26.200  26.420  26.200  26.385   8002.08       NaN
# 1  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85       NaN
# 2  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 3  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 4  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 5  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 6  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 7  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 8  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 9  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 10 2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 11 2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 12 2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 13 2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 14 2024-12-18 13:59:00  26.002  26.130  26.000  26.000   9210.53  0.131571
#
#     limit_price_dist  buy_price
# 0              0.001     26.384
# 1              0.001     26.567
# 2              0.001     26.340
# 3              0.001     26.484
# 4              0.001     26.420
# 5              0.001     26.366
# 6              0.001     26.361
# 7              0.001     26.214
# 8              0.001     26.215
# 9              0.001     26.251
# 10             0.001     26.226
# 11             0.001     26.216
# 12             0.001     26.150
# 13             0.001     26.001
# 14             0.066     25.934
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 1.59156615 and Price: 25.612)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.612
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 25.758
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:46:00  26.386  26.580  26.385  26.568   3962.85       NaN
# 1  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 2  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 3  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 4  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 5  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 6  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 7  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 8  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 9  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 10 2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 11 2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 12 2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 13 2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 14 2024-12-18 14:00:00  25.837  25.839  25.685  25.685  13427.41  0.145929
#
#     limit_price_dist  buy_price
# 0              0.001     26.567
# 1              0.001     26.340
# 2              0.001     26.484
# 3              0.001     26.420
# 4              0.001     26.366
# 5              0.001     26.361
# 6              0.001     26.214
# 7              0.001     26.215
# 8              0.001     26.251
# 9              0.001     26.226
# 10             0.001     26.216
# 11             0.001     26.150
# 12             0.001     26.001
# 13             0.001     25.838
# 14             0.073     25.612
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 1.65265725 and Price: 25.826999999999998)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.826999999999998
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 25.969
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:47:00  26.568  26.655  26.341  26.341   9731.14       NaN
# 1  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 2  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 3  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 4  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 5  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 6  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 7  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 8  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 9  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 10 2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 11 2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 12 2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 13 2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 14 2024-12-18 14:01:00  25.690  25.923  25.690  25.898   8670.20  0.141071
#
#     limit_price_dist  buy_price
# 0              0.001     26.340
# 1              0.001     26.484
# 2              0.001     26.420
# 3              0.001     26.366
# 4              0.001     26.361
# 5              0.001     26.214
# 6              0.001     26.215
# 7              0.001     26.251
# 8              0.001     26.226
# 9              0.001     26.216
# 10             0.001     26.150
# 11             0.001     26.001
# 12             0.001     25.838
# 13             0.001     25.689
# 14             0.071     25.827
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 1.19250615 and Price: 25.881)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.881
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.019
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:48:00  26.387  26.526  26.303  26.485   5158.89       NaN
# 1  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 2  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 3  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 4  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 5  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 6  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 7  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 8  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 9  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 10 2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 11 2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 12 2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 13 2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 14 2024-12-18 14:02:00  25.993  26.019  25.915  25.950   4452.60  0.137357
#
#     limit_price_dist  buy_price
# 0              0.001     26.484
# 1              0.001     26.420
# 2              0.001     26.366
# 3              0.001     26.361
# 4              0.001     26.214
# 5              0.001     26.215
# 6              0.001     26.251
# 7              0.001     26.226
# 8              0.001     26.216
# 9              0.001     26.150
# 10             0.001     26.001
# 11             0.001     25.838
# 12             0.001     25.689
# 13             0.001     25.989
# 14             0.069     25.881
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 0.09072585 and Price: 25.757)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.757
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 25.897000000000002
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:49:00  26.462  26.490  26.410  26.421   2680.57       NaN
# 1  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 2  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 3  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 4  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 5  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 6  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 7  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 8  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 9  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 10 2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 11 2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 12 2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 13 2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 14 2024-12-18 14:03:00  25.907  25.907  25.827  25.827   5326.30  0.140786
#
#     limit_price_dist  buy_price
# 0              0.001     26.420
# 1              0.001     26.366
# 2              0.001     26.361
# 3              0.001     26.214
# 4              0.001     26.215
# 5              0.001     26.251
# 6              0.001     26.226
# 7              0.001     26.216
# 8              0.001     26.150
# 9              0.001     26.001
# 10             0.001     25.838
# 11             0.001     25.689
# 12             0.001     25.989
# 13             0.001     25.909
# 14             0.070     25.757
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 25.896
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:50:00  26.445  26.472  26.366  26.367   3155.81       NaN
# 1  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 2  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 3  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 4  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 5  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 6  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 7  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 8  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 9  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 10 2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 11 2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 12 2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 13 2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 14 2024-12-18 14:04:00  25.804  25.827  25.786  25.827   2405.94  0.138071
#
#     limit_price_dist  buy_price
# 0              0.001     26.366
# 1              0.001     26.361
# 2              0.001     26.214
# 3              0.001     26.215
# 4              0.001     26.251
# 5              0.001     26.226
# 6              0.001     26.216
# 7              0.001     26.150
# 8              0.001     26.001
# 9              0.001     25.838
# 10             0.001     25.689
# 11             0.001     25.989
# 12             0.001     25.909
# 13             0.001     25.807
# 14             0.069     25.758
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 0.6676453499999999 and Price: 25.852)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.852
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 25.998
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:51:00  26.393  26.404  26.337  26.362   2128.10       NaN
# 1  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 2  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 3  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 4  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 5  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 6  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 7  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 8  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 9  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 10 2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 11 2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 12 2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 13 2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 14 2024-12-18 14:05:00  25.902  25.942  25.877  25.925   1187.73  0.146286
#
#     limit_price_dist  buy_price
# 0              0.001     26.361
# 1              0.001     26.214
# 2              0.001     26.215
# 3              0.001     26.251
# 4              0.001     26.226
# 5              0.001     26.216
# 6              0.001     26.150
# 7              0.001     26.001
# 8              0.001     25.838
# 9              0.001     25.689
# 10             0.001     25.989
# 11             0.001     25.909
# 12             0.001     25.807
# 13             0.001     25.942
# 14             0.073     25.852
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 1.74173205 and Price: 25.889999999999997)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.889999999999997
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.032
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:52:00  26.360  26.372  26.205  26.215   2998.46       NaN
# 1  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16       NaN
# 2  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 3  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 4  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 5  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 6  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 7  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 8  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 9  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 10 2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 11 2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 12 2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 13 2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 14 2024-12-18 14:06:00  25.963  25.986  25.949  25.961   1146.80  0.142643
#
#     limit_price_dist  buy_price
# 0              0.001     26.214
# 1              0.001     26.215
# 2              0.001     26.251
# 3              0.001     26.226
# 4              0.001     26.216
# 5              0.001     26.150
# 6              0.001     26.001
# 7              0.001     25.838
# 8              0.001     25.689
# 9              0.001     25.989
# 10             0.001     25.909
# 11             0.001     25.807
# 12             0.001     25.942
# 13             0.001     25.963
# 14             0.071     25.890
# Waiting for the next cycle...
# Dynamic order amount (HYPE): 0.4 (Based on USDC: 0.7035921 and Price: 25.86)
# Order placed: buy 0.4 HYPE/USDC:USDC at 25.86
# Reduce-Only Order placed: sell 0.4 HYPE/USDC:USDC at 26.002000000000002
#              timestamp    open    high     low   close    volume     ATR  \
# 0  2024-12-18 13:53:00  26.212  26.257  26.200  26.216   2977.16     NaN
# 1  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29     NaN
# 2  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50     NaN
# 3  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81     NaN
# 4  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94     NaN
# 5  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68     NaN
# 6  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79     NaN
# 7  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39     NaN
# 8  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78     NaN
# 9  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18     NaN
# 10 2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70     NaN
# 11 2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77     NaN
# 12 2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33     NaN
# 13 2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57     NaN
# 14 2024-12-18 14:07:00  25.950  25.969  25.928  25.931   1428.96  0.1415
#
#     limit_price_dist  buy_price
# 0              0.001     26.215
# 1              0.001     26.251
# 2              0.001     26.226
# 3              0.001     26.216
# 4              0.001     26.150
# 5              0.001     26.001
# 6              0.001     25.838
# 7              0.001     25.689
# 8              0.001     25.989
# 9              0.001     25.909
# 10             0.001     25.807
# 11             0.001     25.942
# 12             0.001     25.963
# 13             0.001     25.963
# 14             0.071     25.860
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:54:00  26.239  26.312  26.218  26.252   4381.29       NaN
# 1  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 2  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 3  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 4  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 5  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 6  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 7  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 8  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 9  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 10 2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 11 2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 12 2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 13 2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 14 2024-12-18 14:08:00  25.941  25.948  25.853  25.859   2096.88  0.141429
#
#     limit_price_dist  buy_price
# 0              0.001     26.251
# 1              0.001     26.226
# 2              0.001     26.216
# 3              0.001     26.150
# 4              0.001     26.001
# 5              0.001     25.838
# 6              0.001     25.689
# 7              0.001     25.989
# 8              0.001     25.909
# 9              0.001     25.807
# 10             0.001     25.942
# 11             0.001     25.963
# 12             0.001     25.963
# 13             0.001     25.939
# 14             0.071     25.788
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:55:00  26.266  26.268  26.227  26.227   1051.50       NaN
# 1  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 2  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 3  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 4  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 5  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 6  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 7  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 8  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 9  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 10 2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 11 2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 12 2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 13 2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53       NaN
# 14 2024-12-18 14:09:00  25.857  25.874  25.828  25.839   1988.51  0.142714
#
#     limit_price_dist  buy_price
# 0              0.001     26.226
# 1              0.001     26.216
# 2              0.001     26.150
# 3              0.001     26.001
# 4              0.001     25.838
# 5              0.001     25.689
# 6              0.001     25.989
# 7              0.001     25.909
# 8              0.001     25.807
# 9              0.001     25.942
# 10             0.001     25.963
# 11             0.001     25.963
# 12             0.001     25.939
# 13             0.001     25.852
# 14             0.071     25.768
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:56:00  26.245  26.250  26.200  26.217   5231.81       NaN
# 1  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 2  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 3  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 4  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 5  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 6  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 7  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 8  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 9  2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 10 2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 11 2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 12 2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53       NaN
# 13 2024-12-18 14:09:00  25.857  25.874  25.828  25.858   2185.02       NaN
# 14 2024-12-18 14:10:00  25.850  25.895  25.689  25.779   8879.43  0.153857
#
#     limit_price_dist  buy_price
# 0              0.001     26.216
# 1              0.001     26.150
# 2              0.001     26.001
# 3              0.001     25.838
# 4              0.001     25.689
# 5              0.001     25.989
# 6              0.001     25.909
# 7              0.001     25.807
# 8              0.001     25.942
# 9              0.001     25.963
# 10             0.001     25.963
# 11             0.001     25.939
# 12             0.001     25.852
# 13             0.001     25.857
# 14             0.077     25.702
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:57:00  26.238  26.305  26.151  26.151   6656.94       NaN
# 1  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68       NaN
# 2  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 3  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 4  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 5  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 6  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 7  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 8  2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 9  2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 10 2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 11 2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53       NaN
# 12 2024-12-18 14:09:00  25.857  25.874  25.828  25.858   2185.02       NaN
# 13 2024-12-18 14:10:00  25.850  25.895  25.666  25.686   9739.43       NaN
# 14 2024-12-18 14:11:00  25.686  25.725  25.553  25.553  24550.20  0.156786
#
#     limit_price_dist  buy_price
# 0              0.001     26.150
# 1              0.001     26.001
# 2              0.001     25.838
# 3              0.001     25.689
# 4              0.001     25.989
# 5              0.001     25.909
# 6              0.001     25.807
# 7              0.001     25.942
# 8              0.001     25.963
# 9              0.001     25.963
# 10             0.001     25.939
# 11             0.001     25.852
# 12             0.001     25.857
# 13             0.001     25.685
# 14             0.078     25.475
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume    ATR  \
# 0  2024-12-18 13:58:00  26.161  26.164  26.002  26.002  15218.68    NaN
# 1  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79    NaN
# 2  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39    NaN
# 3  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78    NaN
# 4  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18    NaN
# 5  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70    NaN
# 6  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77    NaN
# 7  2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33    NaN
# 8  2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57    NaN
# 9  2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75    NaN
# 10 2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53    NaN
# 11 2024-12-18 14:09:00  25.857  25.874  25.828  25.858   2185.02    NaN
# 12 2024-12-18 14:10:00  25.850  25.895  25.666  25.686   9739.43    NaN
# 13 2024-12-18 14:11:00  25.686  25.725  25.551  25.553  25089.19    NaN
# 14 2024-12-18 14:12:00  25.557  25.700  25.551  25.551  10720.43  0.156
#
#     limit_price_dist  buy_price
# 0              0.001     26.001
# 1              0.001     25.838
# 2              0.001     25.689
# 3              0.001     25.989
# 4              0.001     25.909
# 5              0.001     25.807
# 6              0.001     25.942
# 7              0.001     25.963
# 8              0.001     25.963
# 9              0.001     25.939
# 10             0.001     25.852
# 11             0.001     25.857
# 12             0.001     25.685
# 13             0.001     25.552
# 14             0.078     25.473
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 13:59:00  26.002  26.130  25.758  25.839  31929.79       NaN
# 1  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 2  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 3  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 4  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 5  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 6  2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 7  2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 8  2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 9  2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53       NaN
# 10 2024-12-18 14:09:00  25.857  25.874  25.828  25.858   2185.02       NaN
# 11 2024-12-18 14:10:00  25.850  25.895  25.666  25.686   9739.43       NaN
# 12 2024-12-18 14:11:00  25.686  25.725  25.551  25.553  25089.19       NaN
# 13 2024-12-18 14:12:00  25.557  25.700  25.550  25.550  12310.83       NaN
# 14 2024-12-18 14:13:00  25.551  25.578  25.500  25.509   9035.45  0.135071
#
#     limit_price_dist  buy_price
# 0              0.001     25.838
# 1              0.001     25.689
# 2              0.001     25.989
# 3              0.001     25.909
# 4              0.001     25.807
# 5              0.001     25.942
# 6              0.001     25.963
# 7              0.001     25.963
# 8              0.001     25.939
# 9              0.001     25.852
# 10             0.001     25.857
# 11             0.001     25.685
# 12             0.001     25.552
# 13             0.001     25.549
# 14             0.068     25.441
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 14:00:00  25.837  25.839  25.672  25.690  16788.39       NaN
# 1  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 2  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 3  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 4  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 5  2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 6  2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 7  2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 8  2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53       NaN
# 9  2024-12-18 14:09:00  25.857  25.874  25.828  25.858   2185.02       NaN
# 10 2024-12-18 14:10:00  25.850  25.895  25.666  25.686   9739.43       NaN
# 11 2024-12-18 14:11:00  25.686  25.725  25.551  25.553  25089.19       NaN
# 12 2024-12-18 14:12:00  25.557  25.700  25.550  25.550  12310.83       NaN
# 13 2024-12-18 14:13:00  25.551  25.578  25.500  25.520   9388.60       NaN
# 14 2024-12-18 14:14:00  25.527  25.625  25.500  25.501  18678.93  0.132071
#
#     limit_price_dist  buy_price
# 0              0.001     25.689
# 1              0.001     25.989
# 2              0.001     25.909
# 3              0.001     25.807
# 4              0.001     25.942
# 5              0.001     25.963
# 6              0.001     25.963
# 7              0.001     25.939
# 8              0.001     25.852
# 9              0.001     25.857
# 10             0.001     25.685
# 11             0.001     25.552
# 12             0.001     25.549
# 13             0.001     25.519
# 14             0.066     25.435
# Waiting for the next cycle...
# Insufficient balance.
# Failed to place order: hyperliquid {"status":"ok","response":{"type":"order","data":{"statuses":[{"error":"Order has zero size."}]}}}
# Close price is not higher than entry price. No action taken.
#              timestamp    open    high     low   close    volume       ATR  \
# 0  2024-12-18 14:01:00  25.690  25.990  25.690  25.990  11820.78       NaN
# 1  2024-12-18 14:02:00  25.993  26.019  25.870  25.910  11008.18       NaN
# 2  2024-12-18 14:03:00  25.907  25.907  25.800  25.808   7247.70       NaN
# 3  2024-12-18 14:04:00  25.804  25.943  25.786  25.943   5377.77       NaN
# 4  2024-12-18 14:05:00  25.902  26.022  25.877  25.964   4863.33       NaN
# 5  2024-12-18 14:06:00  25.963  25.986  25.949  25.964   2025.57       NaN
# 6  2024-12-18 14:07:00  25.950  25.969  25.928  25.940   1697.75       NaN
# 7  2024-12-18 14:08:00  25.941  25.948  25.840  25.853   2992.53       NaN
# 8  2024-12-18 14:09:00  25.857  25.874  25.828  25.858   2185.02       NaN
# 9  2024-12-18 14:10:00  25.850  25.895  25.666  25.686   9739.43       NaN
# 10 2024-12-18 14:11:00  25.686  25.725  25.551  25.553  25089.19       NaN
# 11 2024-12-18 14:12:00  25.557  25.700  25.550  25.550  12310.83       NaN
# 12 2024-12-18 14:13:00  25.551  25.578  25.500  25.520   9388.60       NaN
# 13 2024-12-18 14:14:00  25.527  25.625  25.500  25.502  18973.49       NaN
# 14 2024-12-18 14:15:00  25.508  25.553  25.455  25.488  18625.48  0.117643
#
#     limit_price_dist  buy_price
# 0              0.001     25.989
# 1              0.001     25.909
# 2              0.001     25.807
# 3              0.001     25.942
# 4              0.001     25.963
# 5              0.001     25.963
# 6              0.001     25.939
# 7              0.001     25.852
# 8              0.001     25.857
# 9              0.001     25.685
# 10             0.001     25.552
# 11             0.001     25.549
# 12             0.001     25.519
# 13             0.001     25.501
# 14             0.059     25.429
# Waiting for the next cycle...
